# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
path1 = '/Users/theojanson/Project/McGillPhysics/HelixRich/Code/Data/'
path2 = '/Users/theojanson/Project/McGillPhysics/HelixRich/Code/Applications/HelixRich/HR-build/'
file = 'cerenkov_test1.txt'

colnames=['X', 'Y', 'Energy'] 
df = pd.read_csv(path1+file, delimiter = "\t", names = colnames)
df = df.dropna(axis = 1)

# %%
df
# Out:
#                  X           Y            Energy
# 0      -120.244280   14.234728  2.95717e-0625942
# 1       -99.540528   69.100728  4.78114e-0625942
# 2        69.980528   96.763828  6.82041e-0625942
# 3       -64.801428  -99.692228  3.98806e-0625942
# 4         8.555763 -117.973280  4.47475e-0625942
# ...            ...         ...               ...
# 219014   64.083628   92.735280  5.42531e-0625942
# 219015   15.813928  114.329280  5.77823e-0625942
# 219016  -38.187428  -96.334128  6.91279e-0625942
# 219017  -46.685928  106.708280   2.3058e-0625942
# 219018   -2.579813    5.065023      32.949925942
#
# [219019 rows x 3 columns]

# %%
df = df[abs(df['X']) < 200]
df = df[abs(df['Y']) < 200]
df['Energy']
df = df[int(df['Energy']) < 40]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-9af9587312ca> in <module>
#       1 df = df[abs(df['X']) < 200]
#       2 df = df[abs(df['Y']) < 200]
# ----> 3 df = df[int(df['Energy']) < 40]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in wrapper(self)
#     129         if len(self) == 1:
#     130             return converter(self.iloc[0])
# --> 131         raise TypeError("cannot convert the series to " "{0}".format(str(converter)))
#     132
#     133     wrapper.__name__ = "__{name}__".format(name=converter.__name__)
#
# TypeError: cannot convert the series to <class 'int'>

# %%
e = df['Energy'].tolist()
plt.hist(e, bins = 5)
# Out:
# (array([46598., 45090., 43520., 42198., 40503.]),
#  array([    0. , 19950.8, 39901.6, 59852.4, 79803.2, 99754. ]),
#  <a list of 5 Patch objects>)
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7ff0541d1b90> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     125         for f_mgr in cls.get_all_fig_managers():
#     126             if force or f_mgr.canvas.figure.stale:
# --> 127                 f_mgr.canvas.draw_idle()
#     128
# ...

# %%
low_e = df[df['Energy'] < 5]
high_e = df[df['Energy'] > 25]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-13a63978cd0b> in <module>
# ----> 1 low_e = df[df['Energy'] < 5]
#       2 high_e = df[df['Energy'] > 25]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1089
#    1090         if is_object_dtype(x.dtype):
# -> 1091             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1092
#    1093         elif is_datetimelike_v_numeric(x, y):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in _comp_method_OBJECT_ARRAY(op, x, y)
# ...

# %%
x_low = low_e['X'].tolist()
y_low = low_e['Y'].tolist()
x_high = high_e['X'].tolist()
y_high = high_e['Y'].tolist()

# %%
plt.scatter(x_low,y_low)

# %%
plt.scatter(x_high,y_high)
